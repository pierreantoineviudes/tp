# %%
import numpy as np

# %%
np.random.randint(0, 100, 100).tolist()
# Out:
# [20,
#  16,
#  52,
#  90,
#  0,
#  9,
#  58,
#  67,
#  19,
#  96,
#  34,
#  72,
#  34,
#  88,
#  45,
#  81,
#  15,
#  86,
#  30,
#  79,
#  42,
#  69,
#  93,
#  59,
#  7,
#  79,
#  93,
#  73,
#  41,
#  92,
#  19,
#  67,
#  30,
#  74,
#  56,
#  62,
#  86,
#  89,
#  94,
#  27,
#  69,
#  94,
#  23,
#  47,
#  92,
#  20,
#  41,
#  99,
#  17,
#  99,
#  78,
#  54,
#  73,
#  15,
#  93,
#  2,
#  72,
#  40,
#  1,
#  91,
#  19,
#  93,
#  87,
#  90,
#  5,
#  26,
#  99,
#  32,
#  69,
#  92,
#  8,
#  73,
#  41,
#  19,
#  12,
#  89,
#  62,
#  27,
#  90,
#  19,
#  36,
#  27,
#  82,
#  47,
#  8,
#  11,
#  77,
#  96,
#  88,
#  1,
#  97,
#  82,
#  57,
#  98,
#  7,
#  89,
#  46,
#  66,
#  44,
#  39]
